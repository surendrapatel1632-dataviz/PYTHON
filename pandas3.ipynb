# %%
import pandas as pd
var=pd.DataFrame({"A":[1,2,3,4],"B":[5,6,7,8]})
var
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
var["C"]=var["A"]+var["B"]
var
# Out:
#    A  B   C
# 0  1  5   6
# 1  2  6   8
# 2  3  7  10
# 3  4  8  12

# %%
var["C"]=var["A"]-var["B"]
var
# Out:
#    A  B  C
# 0  1  5 -4
# 1  2  6 -4
# 2  3  7 -4
# 3  4  8 -4

# %%
var["C"]=var["A"]*var["B"]
var
# Out:
#    A  B   C
# 0  1  5   5
# 1  2  6  12
# 2  3  7  21
# 3  4  8  32

# %%
var["C"]=var["A"]/var["B"]
var
# Out:
#    A  B         C
# 0  1  5  0.200000
# 1  2  6  0.333333
# 2  3  7  0.428571
# 3  4  8  0.500000

# %%
var1=pd.DataFrame({"A":[10,20,30,40],"B":[15,16,17,19]})
var1
# Out:
#     A   B
# 0  10  15
# 1  20  16
# 2  30  17
# 3  40  19

# %%
var1["python"]=var1["A"]<=20
var1
# Out:
#     A   B  python
# 0  10  15    True
# 1  20  16    True
# 2  30  17   False
# 3  40  19   False

# %%
var1["Python_1"]=var1["B"]>=16
var1
# Out:
#     A   B  python  Python_1
# 0  10  15    True     False
# 1  20  16    True      True
# 2  30  17   False      True
# 3  40  19   False      True
