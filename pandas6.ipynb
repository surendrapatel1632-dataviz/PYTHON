# %%
import pandas as pd
csv_1=pd.read_csv("C:\\Users\\suren\\Downloads\\MOCK_DATA.csv")
csv_1
# Out:
#        id first_name last_name                              email  gender  \
# 0       1     Bertie   Brinded                  bbrinded0@ihg.com  Female
# 1       2      Kandy   Boddice                 kboddice1@ucsd.edu  Female
# 2       3       Nomi    Currey            ncurrey2@macromedia.com  Female
# 3       4      Arlyn      Duny                aduny3@usatoday.com  Female
# 4       5   Claretta     Byrne                    cbyrne4@ted.com  Female
# ..    ...        ...       ...                                ...     ...
# 995   996   Julianne      Gaze             jgazern@bravesites.com  Female
# 996   997    Brittni  L'Hommee  blhommeero@nationalgeographic.com  Female
# 997   998      Alyss  Chapling        achaplingrp@arstechnica.com  Female
# 998   999      Danya      Rahl               drahlrq@google.co.jp    Male
# 999  1000      Tania      Love             tloverr@feedburner.com  Female
#
#           ip_address  Unnamed: 6
# 0      148.15.130.67         NaN
# ...

# %%
csv_2=pd.read_csv("C:\\Users\\suren\\Downloads\\MOCK_DATA.csv",nrows=1)
csv_2
# Out:
#    id first_name last_name              email  gender     ip_address  \
# 0   1     Bertie   Brinded  bbrinded0@ihg.com  Female  148.15.130.67
#
#    Unnamed: 6
# 0         NaN

# %%
csv_3=pd.read_csv("C:\\Users\\suren\\Downloads\\MOCK_DATA.csv",nrows=3)
csv_3
# Out:
#    id first_name last_name                    email  gender     ip_address  \
# 0   1     Bertie   Brinded        bbrinded0@ihg.com  Female  148.15.130.67
# 1   2      Kandy   Boddice       kboddice1@ucsd.edu  Female  35.67.128.130
# 2   3       Nomi    Currey  ncurrey2@macromedia.com  Female   140.147.23.6
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN

# %%
csv_4=pd.read_csv("C:\\Users\\suren\\Downloads\\MOCK_DATA.csv",usecols=["last_name","email"])
csv_4
# Out:
#     last_name                              email
# 0     Brinded                  bbrinded0@ihg.com
# 1     Boddice                 kboddice1@ucsd.edu
# 2      Currey            ncurrey2@macromedia.com
# 3        Duny                aduny3@usatoday.com
# 4       Byrne                    cbyrne4@ted.com
# ..        ...                                ...
# 995      Gaze             jgazern@bravesites.com
# 996  L'Hommee  blhommeero@nationalgeographic.com
# 997  Chapling        achaplingrp@arstechnica.com
# 998      Rahl               drahlrq@google.co.jp
# 999      Love             tloverr@feedburner.com
#
# [1000 rows x 2 columns]

# %%
csv_5=pd.read_csv("C:\\Users\\suren\\Downloads\\MOCK_DATA.csv",skiprows=[2])
csv_5
# Out:
#        id first_name last_name                              email  gender  \
# 0       1     Bertie   Brinded                  bbrinded0@ihg.com  Female
# 1       3       Nomi    Currey            ncurrey2@macromedia.com  Female
# 2       4      Arlyn      Duny                aduny3@usatoday.com  Female
# 3       5   Claretta     Byrne                    cbyrne4@ted.com  Female
# 4       6       Rene   Srawley        rsrawley5@deliciousdays.com  Female
# ..    ...        ...       ...                                ...     ...
# 994   996   Julianne      Gaze             jgazern@bravesites.com  Female
# 995   997    Brittni  L'Hommee  blhommeero@nationalgeographic.com  Female
# 996   998      Alyss  Chapling        achaplingrp@arstechnica.com  Female
# 997   999      Danya      Rahl               drahlrq@google.co.jp    Male
# 998  1000      Tania      Love             tloverr@feedburner.com  Female
#
#           ip_address  Unnamed: 6
# 0      148.15.130.67         NaN
# ...

# %%
csv_4=pd.read_csv("C:\\Users\\suren\\Downloads\\MOCK_DATA.csv",index_col="first_name")
csv_4
# Out:
#               id last_name                              email  gender  \
# first_name
# Bertie         1   Brinded                  bbrinded0@ihg.com  Female
# Kandy          2   Boddice                 kboddice1@ucsd.edu  Female
# Nomi           3    Currey            ncurrey2@macromedia.com  Female
# Arlyn          4      Duny                aduny3@usatoday.com  Female
# Claretta       5     Byrne                    cbyrne4@ted.com  Female
# ...          ...       ...                                ...     ...
# Julianne     996      Gaze             jgazern@bravesites.com  Female
# Brittni      997  L'Hommee  blhommeero@nationalgeographic.com  Female
# Alyss        998  Chapling        achaplingrp@arstechnica.com  Female
# Danya        999      Rahl               drahlrq@google.co.jp    Male
# Tania       1000      Love             tloverr@feedburner.com  Female
#
#                  ip_address  Unnamed: 6
# first_name
# Bertie        148.15.130.67         NaN
# ...

# %%
csv_5=pd.read_csv("C:\\Users\\suren\\Downloads\\MOCK_DATA.csv",index_col="first_name",dtype={"id":"float"})
csv_5
# Out:
#                 id last_name                              email  gender  \
# first_name
# Bertie         1.0   Brinded                  bbrinded0@ihg.com  Female
# Kandy          2.0   Boddice                 kboddice1@ucsd.edu  Female
# Nomi           3.0    Currey            ncurrey2@macromedia.com  Female
# Arlyn          4.0      Duny                aduny3@usatoday.com  Female
# Claretta       5.0     Byrne                    cbyrne4@ted.com  Female
# ...            ...       ...                                ...     ...
# Julianne     996.0      Gaze             jgazern@bravesites.com  Female
# Brittni      997.0  L'Hommee  blhommeero@nationalgeographic.com  Female
# Alyss        998.0  Chapling        achaplingrp@arstechnica.com  Female
# Danya        999.0      Rahl               drahlrq@google.co.jp    Male
# Tania       1000.0      Love             tloverr@feedburner.com  Female
#
#                  ip_address  Unnamed: 6
# first_name
# ...
